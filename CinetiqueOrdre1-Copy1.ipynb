# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Vous allez donc commencer par exécuter la ligne de code ci-dessous (dans "a" on me en mémoiré "Hello World"

# %%
a="Hello World"

# %% [markdown]
# Puis exécuter cette autre ligne de code (on écrit ca qu'il y a dans "a")

# %%
print(a)

# %% [markdown]
# Maintenant, l'activité va pouvoir commencer ! Le but est de montrer que la décomposition du saccharose en glucose et fructose est une réaction d'ordre 1.
#
#                     saccharose -> glucose + fructose
#
# Exécuter les cellules les unes après les autres et bien lire les commentaires.
#
# Il ne faut modifier que la partie du document où est indiquée -A compléter-
#
# Ne pas oublier de compléter en même temps le document papier.

# %%
from pylab import *

# %% [markdown]
# Entrée des données expérimentales.
#
# On crée d'abord la variable temps t, 11 valeurs de 0 à 550 puis on affiche les valeurs de t

# %%
t=np.arange(0,550,50)
print(t)

# %% [markdown]
#  Création de la variable concentration avec les données expérimentales (valeurs présentes dans le tableau)

# %%
c = [5,4.52,4.08,3.68,3.33,3,2.71,2.45,2.21,2,1.81]

# %% [markdown]
# Tracé de la concentration en fonction du temps

# %%
plt.plot(t,c,"+",color='blue',label="v")
plt.xlim(0)
plt.ylim(0)

# %% [markdown]
# Calcul de la vitesse de disparition. Calcul de v, la dérivée de la concentration par rapport au temps.
#
# La fonction diff() calcule la différence entre les éléments consécutifs d'une liste  : ici,    diff(c) = c[i+1] - c[i] .

# %%
v = -np.diff(c)/50

# %% [raw]
# # Retrait de la dernière valeur de la liste de c

# %%
cmodifie = delete(c, len(c)-1, 0)

# %% [raw]
# Affichage des valeurs de la vitesse
# Ecrire une ligne permettant d'afficher les valeurs de v puis exécuter le bloc.

# %%
-A compléter-

# %% [raw]
# Tracé de la vitesse de disparition en fonction de la concentration

# %%
plt.plot(cmodifie,v,"+",color='blue',label="v")
plt.title("Evolution de v en fonction de c")

# %% [raw]
# Création, sous forme d'une liste, de la grandeur lnc, logarithme népérien
# # de la concentration

# %%
lnc=[log(i) for i in c]
print(lnc)

# %% [raw]
# Tracé de l'évolution de lnc en fonction du temps
#
# Compléter le bloc suivant afin de tracer l'évolution de lnc en fonction du temps. Une aide est disponible sur le document papier

# %%
plt.plot(-A compléter-)
plt.title(-A compléter-)
plt.xlim(0)
plt.ylim(0)
# Affichage de la grille
plt.grid()
# Affichage des légendes
plt.legend()
# Affichage du graphique
plt.show()
