# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a="Hello World"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(a)

# %% [markdown]
# Maintenant, l'activité va pouvoir commencer ! Le but est, dans une première partie de représenter la trajectoire de la balle. Puis, dans une deuxième partie, on tracera les vecteurs vitesse.
#
# N'oubliez pas d'exécuter les cellules les unes après les autres et de bien lire les commentaires.
#
# Il ne faut modifier que la partie du document où est indiquée -A compléter-
#
# Ne pas oublier de compléter en même temps le document papier.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from pylab import *

# %% [markdown]
# Ci-dessous, les coordonnées de la balle au cours de sa chute. Vous devez retrouver (à peu près !) les valeurs du tableau que vous avez complété !
#
# Au dessous apparait 3 listes de valeurs (chacune entre crochets). La première liste correspond aux valeurs de t (1ère ligne du tableau).
# La deuxième liste correspondant aux abscisses x  de la balle (2 ème ligne du tableau)qu'il faut compléter.
#
# La troisième liste correspondant aux ordonnées y  de la balle (3 ème ligne du tableau)
#
# Par exemple, à t= 0,08 s      y=  14 cm

# %%
t=[0,0.04,0.08,0.12,0.160,0.200,0.240,0.280,0.320]
x=[0,0,0,0,0,0,0,0,0]
y=[0,3.5,8.5,15.5,23.5,35,47.5,62,79]

# %% [markdown]
# Mise en forme du graphique et obtention du graphique ( y en fonction de x)
# On donne un titre au graphique
# puis on met une légende sur les axes
# puis on place les points avec l'instruction plt.scatter. Vous pouvez modifier la couleur des points et/ou la forme des points !

# %%
plt.title("Trajectoire et vitesse lors de la chute de la balle")
plt.xlabel("x (m)")
plt.ylabel("y (m) ")
plt.axis([-1,1,120,10])
plt.scatter(x,y,c ="red",marker='+')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On va maintenant tracer les vecteurs vitesse en chaque point.
#
# Sur le poly, lire le document 5 du poly puis répondre aux questions 1 et 2.
#
# Puis compléter l'instruction suivante en complétant les coordonnées du vecteur vitesse sur l'axe des x pour chaque point.

# %%
vx=[-A compléter-]

# %% [raw]
# On va ensuite compléter la liste avec les coordonnées du vecteur vitesse sur l'axe des y. La liste est vide pour l'instant. Exécuter le bloc (sans compléter la liste vy).

# %%
vy=[]

# %% [raw]
# Sur le poly,lire les instructions dans la question 3 puis répondre aux questions a) et b).
#
# Dans le bloc suivant, on trace à nouveau le graphique puis on y ajoute les vecteurs vitesse en chaque point.
#
# Vous pouvez, par exemple, modifier la largeur de la tête de la flèche.

# %%
plt.title("Trajectoire et vitesse lors de la chute de la balle")
plt.xlabel("x (m)")
plt.ylabel("y (m) ")
plt.axis([-1,1,120,-10])
plt.scatter(x,y,c ="red",marker='+')
for i in range (0,len(t)-1):
    vy.append((y[i+1]-y[i])/(t[i+1]-t[i])) # calcul de la coordonnée vy
    print(vy[i],'vy')
    # Tracé du vecteur vitesse
    plt.arrow(x[i], y[i], vx[i]/1, vy[i]/40,head_width=0.06, head_length=0.9,length_includes_head= True)
plt.show()
