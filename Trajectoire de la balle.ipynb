# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a="Hello World"

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(a)

# %% [markdown]
# Maintenant, l'activité va pouvoir commencer ! Le but est de réaliser la partie numérique du TP. Vous allez compléter les listes  x et y en suivant les instructions suivantes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Exécuter la cellule suivante puis continuer.

# %%
import matplotlib.pyplot as plt # importation de la bibliothèque des représentations graphiques

# %% [markdown]
# Compléter les listes x et y avec les valeurs obtenues lors du TP (1ère ligne du tableau (pour x) et 3ème ligne (pour y))

# %%
x=[0,0,0,0,0,0,0,0,0]
y=[0,6,14,23,33,45,57,72,87]

# %% [markdown]
# Les instructions suivantes permettent d'obtenir le graphique.

# %%
plt.scatter(x,y) # Trace un graphique point par point
plt.show() # indispensable pour que la fenêtre graphique s'affiche

# %% [raw]
# Compléter la cellule précédente afin de mettre en forme le graphique :
# On donne un titre au graphique
# puis on met une légende sur les axes
# puis on place les points avec l'instruction plt.scatter. Vous pouvez modifier la couleur des points et/ou la forme des points ! Il faut suivre ce qui est noté sur le poly de TP.
